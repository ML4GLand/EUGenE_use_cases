# %%
import torch

# %%
torch.cuda.is_available()
# Out:
# True

# %%
from eugene import models

# %%
model = models.DeepSTARR.load_from_checkpoint("/cellar/users/aklie/projects/ML4GLand/use_cases/deAlmeida22/models/eugene/DeepSTARR.ckpt")

# %%
from eugene import settings

# %%
settings.dataset_dir = "/cellar/users/aklie/data/eugene"

# %%
from eugene import datasets
from eugene import preprocess as pp

# %%
sdata_test = datasets.deAlmeida22("test")
pp.ohe_seqs_sdata(sdata_test)
# Out:
# Path /cellar/users/aklie/data/eugene/deAlmeida22 does not exist, creating new folder.
# Downloading deAlmeida22 Sequences_Test.fa?download=1 to /cellar/users/aklie/data/eugene/deAlmeida22...
# Finished downloading Sequences_Test.fa?download=1
# Downloading deAlmeida22 Sequences_activity_Test.txt?download=1 to /cellar/users/aklie/data/eugene/deAlmeida22...
# Finished downloading Sequences_activity_Test.txt?download=1
# HBox(children=(FloatProgress(value=0.0, description='One-hot encoding sequences', max=41186.0, style=ProgressS…
# SeqData object modified:
# 	ohe_seqs: None -> 41186 ohe_seqs added

# %%
preds = model.predict(sdata_test.ohe_seqs, batch_size=128).detach().numpy()

# %%
preds
# Out:
# array([[ 2.597928  ,  1.0902203 ],
#        [ 0.2787927 , -0.2589017 ],
#        [ 1.6473565 ,  0.32089677],
#        ...,
#        [-0.36633873, -0.5662008 ],
#        [-0.19394946,  0.32826483],
#        [-0.60908985, -0.66063523]], dtype=float32)

# %%
res_df = sdata_test.seqs_annot

# %%
res_df['Dev_log2_enrichment_scaled_pred'] = preds[:, 0]
res_df['Hk_log2_enrichment_scaled_pred'] = preds[:, 1]

# %%
res_df
# Out:
#                                           Dev_log2_enrichment  \
# chr2R_10574736_10574984_+_positive_peaks             3.418306
# chr2R_10577049_10577297_+_positive_peaks             2.211545
# chr2R_10600762_10601010_+_positive_peaks             3.483831
# chr2R_10601947_10602195_+_positive_peaks             1.739022
# chr2R_10605176_10605424_+_positive_peaks             4.829350
# ...                                                       ...
# chr2R_21141601_21141849_-_negative                   0.104630
# chr2R_21141901_21142149_-_negative                  -1.318970
# chr2R_21142401_21142649_-_negative                   0.681030
# chr2R_21142501_21142749_-_negative                   1.144431
# chr2R_21143801_21144049_-_negative                   0.615935
#
#                                           Hk_log2_enrichment  \
# chr2R_10574736_10574984_+_positive_peaks            1.983081
# chr2R_10577049_10577297_+_positive_peaks           -0.379982
# chr2R_10600762_10601010_+_positive_peaks            1.434863
# chr2R_10601947_10602195_+_positive_peaks            0.147684
# chr2R_10605176_10605424_+_positive_peaks            0.794047
# ...                                                      ...
# chr2R_21141601_21141849_-_negative                 -0.644837
# chr2R_21141901_21142149_-_negative                  0.663313
# chr2R_21142401_21142649_-_negative                 -2.151505
# chr2R_21142501_21142749_-_negative                 -1.877330
# chr2R_21143801_21144049_-_negative                 -1.205953
#
#                                           Dev_log2_enrichment_scaled  \
# chr2R_10574736_10574984_+_positive_peaks                    2.019106
# chr2R_10577049_10577297_+_positive_peaks                    1.225755
# chr2R_10600762_10601010_+_positive_peaks                    2.062184
# chr2R_10601947_10602195_+_positive_peaks                    0.915108
# chr2R_10605176_10605424_+_positive_peaks                    2.946757
# ...                                                              ...
# chr2R_21141601_21141849_-_negative                         -0.159378
# chr2R_21141901_21142149_-_negative                         -1.095283
# chr2R_21142401_21142649_-_negative                          0.219561
# chr2R_21142501_21142749_-_negative                          0.524210
# chr2R_21143801_21144049_-_negative                          0.176766
#
#                                           Hk_log2_enrichment_scaled  \
# chr2R_10574736_10574984_+_positive_peaks                   1.249387
# chr2R_10577049_10577297_+_positive_peaks                  -0.182038
# chr2R_10600762_10601010_+_positive_peaks                   0.917304
# chr2R_10601947_10602195_+_positive_peaks                   0.137596
# chr2R_10605176_10605424_+_positive_peaks                   0.529130
# ...                                                             ...
# chr2R_21141601_21141849_-_negative                        -0.342474
# chr2R_21141901_21142149_-_negative                         0.449938
# chr2R_21142401_21142649_-_negative                        -1.255139
# chr2R_21142501_21142749_-_negative                        -1.089057
# chr2R_21143801_21144049_-_negative                        -0.682370
#
#                                           Dev_log2_enrichment_quantile_normalized  \
# chr2R_10574736_10574984_+_positive_peaks                                 3.722761
# chr2R_10577049_10577297_+_positive_peaks                                 1.893053
# chr2R_10600762_10601010_+_positive_peaks                                 3.808864
# chr2R_10601947_10602195_+_positive_peaks                                 1.383562
# chr2R_10605176_10605424_+_positive_peaks                                 5.325903
# ...                                                                           ...
# chr2R_21141601_21141849_-_negative                                      -0.126663
# chr2R_21141901_21142149_-_negative                                      -1.506605
# chr2R_21142401_21142649_-_negative                                       0.395427
# chr2R_21142501_21142749_-_negative                                       0.832398
# chr2R_21143801_21144049_-_negative                                       0.336508
#
#                                           Hk_log2_enrichment_quantile_normalized  \
# chr2R_10574736_10574984_+_positive_peaks                                2.231366
# chr2R_10577049_10577297_+_positive_peaks                               -0.146984
# chr2R_10600762_10601010_+_positive_peaks                                1.773922
# chr2R_10601947_10602195_+_positive_peaks                                0.440031
# chr2R_10605176_10605424_+_positive_peaks                                1.138698
# ...                                                                          ...
# chr2R_21141601_21141849_-_negative                                     -0.437401
# chr2R_21141901_21142149_-_negative                                      0.991691
# chr2R_21142401_21142649_-_negative                                     -1.949659
# chr2R_21142501_21142749_-_negative                                     -1.685165
# chr2R_21143801_21144049_-_negative                                     -1.023438
#
#                                           Dev_log2_enrichment_scaled_pred  \
# chr2R_10574736_10574984_+_positive_peaks                         2.597928
# chr2R_10577049_10577297_+_positive_peaks                         0.278793
# chr2R_10600762_10601010_+_positive_peaks                         1.647357
# chr2R_10601947_10602195_+_positive_peaks                         1.646005
# chr2R_10605176_10605424_+_positive_peaks                         1.352599
# ...                                                                   ...
# chr2R_21141601_21141849_-_negative                              -0.580536
# chr2R_21141901_21142149_-_negative                              -0.569130
# chr2R_21142401_21142649_-_negative                              -0.366339
# chr2R_21142501_21142749_-_negative                              -0.193949
# chr2R_21143801_21144049_-_negative                              -0.609090
#
#                                           Hk_log2_enrichment_scaled_pred
# chr2R_10574736_10574984_+_positive_peaks                        1.090220
# chr2R_10577049_10577297_+_positive_peaks                       -0.258902
# chr2R_10600762_10601010_+_positive_peaks                        0.320897
# chr2R_10601947_10602195_+_positive_peaks                        0.790095
# chr2R_10605176_10605424_+_positive_peaks                        0.240036
# ...                                                                  ...
# chr2R_21141601_21141849_-_negative                             -0.226378
# chr2R_21141901_21142149_-_negative                             -0.684690
# chr2R_21142401_21142649_-_negative                             -0.566201
# chr2R_21142501_21142749_-_negative                              0.328265
# chr2R_21143801_21144049_-_negative                             -0.660635
#
# [41186 rows x 8 columns]

# %%
# plot the predictions in a scatter plot
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import gaussian_kde
import numpy as np

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 5))

# Get point densities
x = res_df['Dev_log2_enrichment_scaled']
y = res_df['Dev_log2_enrichment_scaled_pred']
xy = np.vstack([x,y])
z = gaussian_kde(xy)(xy)

# Sort the points by density, so that the densest points are plotted last
idx = z.argsort()
x, y, z = x[idx], y[idx], z[idx]

ax[0].scatter(x, y, c=z)

# Get point densities
x = res_df['Hk_log2_enrichment_scaled']
y = res_df['Hk_log2_enrichment_scaled_pred']
xy = np.vstack([x,y])
z = gaussian_kde(xy)(xy)

# Sort the points by density, so that the densest points are plotted last
idx = z.argsort()
x, y, z = x[idx], y[idx], z[idx]

ax[1].scatter(x, y, c=z)

# Add metrics to the plots
from sklearn.metrics import r2_score
from scipy.stats import pearsonr, spearmanr

r2_dev = r2_score(res_df['Dev_log2_enrichment_scaled'], res_df['Dev_log2_enrichment_scaled_pred'])
r2_hk = r2_score(res_df['Hk_log2_enrichment_scaled'], res_df['Hk_log2_enrichment_scaled_pred'])

pearson_dev = pearsonr(res_df['Dev_log2_enrichment_scaled'], res_df['Dev_log2_enrichment_scaled_pred'])
pearson_hk = pearsonr(res_df['Hk_log2_enrichment_scaled'], res_df['Hk_log2_enrichment_scaled_pred'])

spearman_dev = spearmanr(res_df['Dev_log2_enrichment_scaled'], res_df['Dev_log2_enrichment_scaled_pred'])
spearman_hk = spearmanr(res_df['Hk_log2_enrichment_scaled'], res_df['Hk_log2_enrichment_scaled_pred'])

ax[0].set_title(f"Dev R2: {r2_dev:.2f}\nPearson: {pearson_dev[0]:.2f}\nSpearman: {spearman_dev[0]:.2f}")
ax[1].set_title(f"Hk R2: {r2_hk:.2f}\nPearson: {pearson_hk[0]:.2f}\nSpearman: {spearman_hk[0]:.2f}")

# Add a diagonal line to the plots
ax[0].plot(ax[0].get_xlim(), ax[0].get_ylim(), ls="--", c=".3")
ax[1].plot(ax[1].get_xlim(), ax[1].get_ylim(), ls="--", c=".3")

plt.tight_layout()
plt.show()

# %% [markdown]
# # Interpret

# %%
import seqexplainer as se

# %%
contribs = se.attribute(
    model, 
    sdata_test.ohe_seqs,
    method="GradientShap",
    reference_type="zero",
    target=0,
    batch_size=128
)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Computing attributions on batches of size 128', max=322.0…
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1400996/1178711756.py in <module>
#       5     reference_type="zero",
#       6     target=0,
# ----> 7     batch_size=128
#       8 )
#
# ~/projects/ML4GLand/SeqExplainer/seqexplainer/_attributions.py in attribute(model, inputs, method, reference_type, target, batch_size, device)
#     191             target=target,
#     192             device=device,
# --> 193             **kwargs
#     194         )
#     195         attrs.append(curr_attrs)
#
# ~/projects/ML4GLand/SeqExplainer/seqexplainer/_attributions.py in _captum_attributions(model, inputs, method, target, device, **kwargs)
#     129         inputs = torch.tensor(inputs)
#     130     attributor = CAPTUM_REGISTRY[method](model)
# --> 131     attrs = attributor.attribute(inputs=inputs, target=target, **kwargs)
#     132     return attrs
#     133
#
# ~/opt/miniconda3/envs/eugene_dev/lib/python3.7/site-packages/captum/log/__init__.py in wrapper(*args, **kwargs)
#      33             @wraps(func)
#      34             def wrapper(*args, **kwargs):
# ---> 35                 return func(*args, **kwargs)
#      36
#      37             return wrapper
#
# ~/opt/miniconda3/envs/eugene_dev/lib/python3.7/site-packages/captum/attr/_core/gradient_shap.py in attribute(self, inputs, baselines, n_samples, stdevs, target, additional_forward_args, return_convergence_delta)
#     277             target=target,
#     278             additional_forward_args=additional_forward_args,
# --> 279             return_convergence_delta=return_convergence_delta,
#     280         )
#     281
#
# ~/opt/miniconda3/envs/eugene_dev/lib/python3.7/site-packages/captum/attr/_core/noise_tunnel.py in attribute(self, inputs, nt_type, nt_samples, nt_samples_batch_size, stdevs, draw_baseline_from_distrib, **kwargs)
#     362                     is_attrib_tuple,
#     363                     delta_partial,
# --> 364                 ) = compute_partial_attribution(inputs_with_noise, kwargs_copy)
#     365
#     366                 if len(sum_attributions) == 0:
#
# ~/opt/miniconda3/envs/eugene_dev/lib/python3.7/site-packages/captum/attr/_core/noise_tunnel.py in compute_partial_attribution(inputs_with_noise_partition, kwargs_partition)
#     255                 if is_inputs_tuple
#     256                 else inputs_with_noise_partition[0],
# --> 257                 **kwargs_partition,
#     258             )
#     259             delta = None
#
# ~/opt/miniconda3/envs/eugene_dev/lib/python3.7/site-packages/captum/attr/_core/gradient_shap.py in attribute(self, inputs, baselines, target, additional_forward_args, return_convergence_delta)
#     365         )
#     366         grads = self.gradient_func(
# --> 367             self.forward_func, input_baseline_scaled, target, additional_forward_args
#     368         )
#     369
#
# ~/opt/miniconda3/envs/eugene_dev/lib/python3.7/site-packages/captum/_utils/gradient.py in compute_gradients(forward_fn, inputs, target_ind, additional_forward_args)
#     110     with torch.autograd.set_grad_enabled(True):
#     111         # runs forward pass
# --> 112         outputs = _run_forward(forward_fn, inputs, target_ind, additional_forward_args)
#     113         assert outputs[0].numel() == 1, (
#     114             "Target not provided when necessary, cannot"
#
# ~/opt/miniconda3/envs/eugene_dev/lib/python3.7/site-packages/captum/_utils/common.py in _run_forward(forward_func, inputs, target, additional_forward_args)
#     457         *(*inputs, *additional_forward_args)
#     458         if additional_forward_args is not None
# --> 459         else inputs
#     460     )
#     461     return _select_targets(output, target)
#
# ~/opt/miniconda3/envs/eugene_dev/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/projects/ML4GLand/EUGENe/eugene/models/_basic_models.py in forward(self, x, x_rev_comp)
#    1491         x = self.conv1d_tower(x)
#    1492         x = x.view(x.size(0), self.conv1d_tower.flatten_dim)
# -> 1493         x = self.dense_block(x)
#    1494         return x
#    1495
#
# ~/opt/miniconda3/envs/eugene_dev/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/projects/ML4GLand/EUGENe/eugene/models/base/_blocks.py in forward(self, x)
#     214
#     215     def forward(self, x):
# --> 216         return self.layers(x)
#     217
#     218
#
# ~/opt/miniconda3/envs/eugene_dev/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/opt/miniconda3/envs/eugene_dev/lib/python3.7/site-packages/torch/nn/modules/container.py in forward(self, input)
#     202     def forward(self, input):
#     203         for module in self:
# --> 204             input = module(input)
#     205         return input
#     206
#
# ~/opt/miniconda3/envs/eugene_dev/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/opt/miniconda3/envs/eugene_dev/lib/python3.7/site-packages/torch/nn/modules/linear.py in forward(self, input)
#     112
#     113     def forward(self, input: Tensor) -> Tensor:
# --> 114         return F.linear(input, self.weight, self.bias)
#     115
#     116     def extra_repr(self) -> str:
#
# KeyboardInterrupt:

# %%
se._attributions.plot_attribution_logo(
    contribs[0],
)
